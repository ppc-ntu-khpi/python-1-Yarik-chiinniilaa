# %%
C = [10.0, 15.5, 17.1, 17.6, 19.0, 19.9, 25.8, 28.0, 29.0, 30.1]

F = []
for t in C:
    f_temp = t * 9/5 + 32
    F.append(round(f_temp, 1))
    
    F = F[::-1]
    
    print(F)
    print("Всього вимірювань:", len(F))
# Out:
# [50.0]
# Всього вимірювань: 1
# [59.9, 50.0]
# Всього вимірювань: 2
# [62.8, 50.0, 59.9]
# Всього вимірювань: 3
# [63.7, 59.9, 50.0, 62.8]
# Всього вимірювань: 4
# [66.2, 62.8, 50.0, 59.9, 63.7]
# Всього вимірювань: 5
# [67.8, 63.7, 59.9, 50.0, 62.8, 66.2]
# Всього вимірювань: 6
# [78.4, 66.2, 62.8, 50.0, 59.9, 63.7, 67.8]
# Всього вимірювань: 7
# [82.4, 67.8, 63.7, 59.9, 50.0, 62.8, 66.2, 78.4]
# Всього вимірювань: 8
# [84.2, 78.4, 66.2, 62.8, 50.0, 59.9, 63.7, 67.8, 82.4]
# Всього вимірювань: 9
# [86.2, 82.4, 67.8, 63.7, 59.9, 50.0, 62.8, 66.2, 78.4, 84.2]
# Всього вимірювань: 10

# %%
grades = (4, 5, 4, 3, 4, 3, 5, 3, 2, 3, 5, 5, 5)

if 2 in grades:
    print('Студент має принаймні одну двійку з дисципліни!')
else:
    print('Студент вчиться без двійок!')
# Out:
# Студент має принаймні одну двійку з дисципліни!

# %%
students = {"Васильєв":3.5, "Семенов":4.0, "Петров":4.5, "Іванов":3.0, "Мар'їн":5.0}

for student in students.keys():
    new_grade = students[student] + 1
    students[student] = new_grade if new_grade <= 5 else 5.0

print(students)
# Out:
# {'Васильєв': 4.5, 'Семенов': 5.0, 'Петров': 5.0, 'Іванов': 4.0, "Мар'їн": 5.0}

# %%
responses = ["Іванов", "Петров", "Сидоров", "Васильєв", "Семенов",
             "Іванов", "Марьїн", "Сидоров", "Дмитрієв", "Іванов"]

print("Всього анкет заповнено:", len(responses))

respondents = set(responses)

print("Всього респондентів:", len(respondents))
# Out:
# Всього анкет заповнено: 10
# Всього респондентів: 7

# %%
def sqPlus1(x):
    return x**2 + 1
numbers = []
n = 1

while True:
    if n <= 10:
        x = int(input(str(n) + " - введіть число від 0 до 10: "))

        if 0 <= x <= 10:
            numbers.append(sqPlus1(x))
            n = n + 1
        else:
            print("Потрібне число від 0 до 10!")
    else:
            break
    
    numbers

# %%
add = lambda a, b: a + b
sub = lambda a, b: a - b
mul = lambda a, b: a * b
div = lambda a, b: a / b if b != 0 else 0

a = int(input("Введіть перше число:"))
b = int(input("Введіть друге число:"))
c = 0

menu = {}
menu['1']="Додати числа" 
menu['2']="Відняти числа"
menu['3']="Перемножити числа"
menu['4']="Поділити числа"
menu['5']="завершити роботу"
options=menu.keys()
for entry in options: 
    print(entry, menu[entry])
while True:   
  selection=input("Оберіть операцію:") 
  if selection =='1': 
    print("Додавання:", add(a, b))
  elif selection == '2': 
    print("Віднімання:", sub(a, b))
  elif selection == '3':
    print("Множення:",mul(a, b))
  elif selection == '4': 
    print("Ділення",div(a, b))
  elif selection == '5': 
    break
  else: 
    print ("Невідома операція!")
# Out:
# 1 Додати числа
# 2 Відняти числа
# 3 Перемножити числа
# 4 Поділити числа
# 5 завершити роботу
# Додавання: 10
# Віднімання: 0
# Множення: 25
# Ділення 1.0
# Невідома операція!

# %%
def controlEngine(id, name, operation = "стоп", priority = "високий"):
    print('Агрегат:',name, '#',id, "\n\tОбрана операція:", operation ,"\n\tПриорітет:", priority)
    
controlEngine(1,"реактор")
controlEngine(1,"реактор","запуск")
controlEngine(1,"реактор", priority="звичайний")
controlEngine(operation = "запуск", id = 1,name = "реактор", priority = "звичайний")
# Out:
# Агрегат: реактор # 1
# 	Обрана операція: стоп
# 	Приорітет: високий
# Агрегат: реактор # 1
# 	Обрана операція: запуск
# 	Приорітет: високий
# Агрегат: реактор # 1
# 	Обрана операція: стоп
# 	Приорітет: звичайний
# Агрегат: реактор # 1
# 	Обрана операція: запуск
# 	Приорітет: звичайний
